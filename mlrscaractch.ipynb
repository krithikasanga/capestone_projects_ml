# %% [markdown]
# <a href="https://colab.research.google.com/github/krithikasanga/capestone_projects_ml/blob/main/mlrscaractch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes
import numpy as np

X,y=load_diabetes(return_X_y=True)
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape
# Out:
# (353, 10)

# %%
X_test.shape
# Out:
# (89, 10)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %% [markdown]
# code from scratch

# %% [markdown]
# $$
# \hat{\beta} = (X^T X)^{-1} X^T y
# $$

# %%
X_train.shape
# Out:
# (353, 10)

# %%
X_train=np.insert(X_train,0,1,axis=1)
X_train.shape
# Out:
# (353, 11)

# %%
class mr:
  def __init__(self):
    self.intercept_=None
    self.coeff_=None
  def fit(self,X_train,y_train):
    X_train=np.insert(X_train,0,1,axis=1)
    betas=np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T,y_train)
    self.intercept_=betas[0]
    self.coeff_=betas[1:]
  def predict(self,X_test):
    y_pred=np.dot(X_test,self.coeff_)+self.intercept_
    return y_pred

# %%
m=mr()
m.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /tmp/ipykernel_13666/342403195.py in <cell line: 0>()
#       1 m=mr()
# ----> 2 m.fit(X_train,y_train)
#
# /tmp/ipykernel_13666/3515596090.py in fit(self, X_train, y_train)
#       5   def fit(self,X_train,y_train):
#       6     X_train=np.insert(X_train,0,1,axis=1)
# ----> 7     betas=np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T,y_train)
#       8     self.intercept_=betas[0]
#       9     self.coeff_=betas[1:]
#
# /usr/local/lib/python3.12/dist-packages/numpy/linalg/_linalg.py in inv(a)
#     606     with errstate(call=_raise_linalgerror_singular, invalid='call',
#     607                   over='ignore', divide='ignore', under='ignore'):
# --> 608         ainv = _umath_linalg.inv(a, signature=signature)
#     609     return wrap(ainv.astype(result_t, copy=False))
#     610
#
# ...
