# %% [markdown]
# <a href="https://colab.research.google.com/github/krithikasanga/capestone_projects_ml/blob/main/mlr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    feature1  feature2      target
# 0  0.162344  1.745645  138.585196
# 1 -0.387466 -1.124674  -71.783375
# 2 -1.642539  1.305808  -44.221592
# 3 -0.406540  0.509630  -31.816355
# 4 -0.423173  1.229215   50.038072

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=3)

# %%
X_train.shape
# Out:
# (80, 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
print("R2 SCORE:",r2_score(y_test,y_pred))
# Out:
# MAE: 37.032144389016175
# MSE: 2679.5420870347384
# R2 SCORE: 0.8358396241184044

# %%
# Step 1: Create values for both independent variables
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)

# Step 2: Create mesh grid (all combinations of x and y)
xGrid, yGrid = np.meshgrid(x, y)

# Step 3: Prepare input data for prediction
# ravel() converts the 10x10 grid into 100 values
# reshape(1,100) makes it a row vector
# vstack stacks both features
# transpose converts it into shape (100,2)
final = np.vstack((xGrid.ravel().reshape(1,100), yGrid.ravel().reshape(1,100))).T

# Step 4: Predict target values using trained MLR model
z_final = lr.predict(final)

# Step 5: Convert predictions back to grid shape
z = z_final.reshape(10,10)

# %%
# Create scatter plot of dataset
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

# Add regression plane
fig.add_trace(
    go.Surface(
        x = xGrid,   # use grid, not x
        y = yGrid,   # use grid, not y
        z = z,
        opacity = 0.6
    )
)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
lr.coef_
# Out:
# array([79.39131508, 71.58194521])

# %%
lr.intercept_
# Out:
# np.float64(11.899727397553884)
